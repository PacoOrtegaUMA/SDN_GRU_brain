# %%
import os
import re
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# ============================================================
ROOT_RESULTS = "Results_min"
COL_REAL     = "Realidad"
COL_PRED     = "Prediccion"
OUTPUT_CSV   = "Results_min/comparativa_arq.csv"
TRIGGER      = 1000

FUENTES_BASELINE = [
    ("ARIMA", "results_baselines_1min", "test_results_", "_baselines.csv"),
    ("Naive", "results_baselines_1min", "test_results_", "_baselines.csv"),
]
# ============================================================

PATRON_ARQ = re.compile(
    r"^results_Arq(\d+)_(\d+)m_([AB])_W(\d+)_p(\d+)_H(\d+)$"
)


def mape(y_real, y_pred):
    mask = y_real > 1e-6
    return np.mean(np.abs((y_real[mask] - y_pred[mask]) / y_real[mask])) * 100 if mask.sum() > 0 else np.nan


def calcular_metricas(y_real, y_pred, trigger=None):
    mask_nan = ~(np.isnan(y_real) | np.isnan(y_pred))
    y_real, y_pred = y_real[mask_nan], y_pred[mask_nan]
    if trigger is not None:
        m = y_real > trigger
        y_real, y_pred = y_real[m], y_pred[m]
    if len(y_real) == 0:
        return None, None, None, 0
    mae  = mean_absolute_error(y_real, y_pred)
    rmse = np.sqrt(mean_squared_error(y_real, y_pred))
    mp   = mape(y_real, y_pred)
    return round(mae, 2), round(rmse, 2), round(mp, 2), len(y_real)


def es_enlace_valido(enlace):
    partes = enlace.split("_")
    return len(partes) == 2 and all(len(p) >= 2 for p in partes)


# ── NUEVO: caracterización del tráfico real por enlace ───────
def caracterizar_enlaces(carpeta_rel, prefijo, sufijo, trigger=None):
    """
    Lee la columna Realidad de los CSVs de baseline y calcula
    CV%, PicoRatio y P99 por enlace.
    """
    carpeta_abs = os.path.join(ROOT_RESULTS, carpeta_rel)
    resultado   = {}
    if not os.path.exists(carpeta_abs):
        return resultado
    for f in sorted(os.listdir(carpeta_abs)):
        if not f.startswith(prefijo) or not f.endswith(sufijo):
            continue
        enlace = f[len(prefijo): len(f) - len(sufijo)]
        if not enlace or not es_enlace_valido(enlace):
            continue
        try:
            df = pd.read_csv(os.path.join(carpeta_abs, f))
            v  = pd.to_numeric(df[COL_REAL], errors="coerce").dropna()
            if trigger is not None:
                v = v[v > trigger]
            if len(v) == 0:
                continue
            media = v.mean()
            std   = v.std()
            resultado[enlace] = {
                "CV%":       round(std / media * 100, 1) if media > 0 else np.nan,
                "PicoRatio": round(v.max() / media, 1)  if media > 0 else np.nan,
                "P99":       round(np.percentile(v, 99), 2),
            }
        except Exception as e:
            print(f"   ❌ caracterización {f}: {e}")
    return resultado


def leer_carpeta_arq(carpeta_abs, prefijo):
    resultados = {}
    if not os.path.exists(carpeta_abs):
        return resultados
    for f in sorted(os.listdir(carpeta_abs)):
        if not f.startswith(prefijo) or not f.endswith(".csv"):
            continue
        enlace = f[len(prefijo):-4]
        if not enlace or not es_enlace_valido(enlace):
            continue
        try:
            df = pd.read_csv(os.path.join(carpeta_abs, f))
            if COL_REAL not in df.columns or COL_PRED not in df.columns:
                continue
            y_real = df[COL_REAL].values.astype(float)
            y_pred = df[COL_PRED].values.astype(float)
            mae, rmse, mp, n = calcular_metricas(y_real, y_pred, TRIGGER)
            if mae is not None:
                resultados[enlace] = {"MAE": mae, "RMSE": rmse, "MAPE": mp, "N": n}
        except Exception as e:
            print(f"   ❌ {f}: {e}")
    return resultados


def leer_baseline(etiqueta, carpeta_rel, prefijo, sufijo, horizonte):
    col = f"{etiqueta}_t+{horizonte}"
    carpeta_abs = os.path.join(ROOT_RESULTS, carpeta_rel)
    resultados = {}
    if not os.path.exists(carpeta_abs):
        return resultados
    for f in sorted(os.listdir(carpeta_abs)):
        if not f.startswith(prefijo) or not f.endswith(sufijo):
            continue
        enlace = f[len(prefijo): len(f) - len(sufijo)]
        if not enlace or not es_enlace_valido(enlace):
            continue
        try:
            df = pd.read_csv(os.path.join(carpeta_abs, f))
            if COL_REAL not in df.columns or col not in df.columns:
                continue
            y_real = df[COL_REAL].values.astype(float)
            y_pred = df[col].values.astype(float)
            mae, rmse, mp, n = calcular_metricas(y_real, y_pred, TRIGGER)
            if mae is not None:
                resultados[enlace] = {"MAE": mae, "RMSE": rmse, "MAPE": mp, "N": n}
        except Exception as e:
            print(f"   ❌ {f}: {e}")
    return resultados


def fila_global(df_enlaces, cols_modelo, metrica):
    fila = {"Enlace": "── GLOBAL ──"}
    for m in cols_modelo:
        col = f"{metrica}_{m}"
        fila[col] = round(df_enlaces[col].dropna().mean(), 2) if col in df_enlaces else None
    vals = {m: fila[f"{metrica}_{m}"] for m in cols_modelo if fila.get(f"{metrica}_{m}") is not None}
    fila[f"mejor_{metrica}"] = min(vals, key=vals.get) if vals else "-"
    return fila


def ordenar_columnas_modelo(cols_modelo):
    baselines_orden = ["ARIMA", "Naive"]
    baselines = [c for c in baselines_orden if c in cols_modelo]
    arq_cols  = [c for c in cols_modelo if c not in baselines_orden]

    def sort_key(etiq):
        m = re.match(r"Arq(\d+)_([AB])", etiq)
        if m:
            return (int(m.group(1)), 0 if m.group(2) == "A" else 1)
        return (99, 99)

    return baselines + sorted(arq_cols, key=sort_key)


def imprimir_tabla(df, metrica, cols_modelo, horizonte, ventana, peso, trigger):
    ancho       = 14
    ancho_car   = 10
    trigger_str = f" | Realidad > {trigger:,.0f}" if trigger else ""
    peso_fmt    = f"{int(peso)/100:.2f}"
    print(f"\n{'='*140}")
    print(f" {metrica} — t+{horizonte}min | W={ventana} | peso={peso_fmt}{trigger_str}")
    print(f"{'='*140}")

    # Cabecera: columnas de caracterización + modelos
    header = (f"{'Enlace':>15}"
              f"  {'CV%':>{ancho_car}}  {'PicoRatio':>{ancho_car}}  {'P99':>{ancho_car}}"
              + "".join(f"  {m:>{ancho}}" for m in cols_modelo)
              + f"  {'mejor':>{ancho}}")
    print(header)
    print("-" * len(header))

    for _, row in df[df["Enlace"] != "── GLOBAL ──"].iterrows():
        cv   = row.get("CV%");       cv_s   = f"{cv:.1f}"   if pd.notna(cv)   else "-"
        pr   = row.get("PicoRatio"); pr_s   = f"{pr:.1f}"   if pd.notna(pr)   else "-"
        p99  = row.get("P99");       p99_s  = f"{p99:.2e}"  if pd.notna(p99)  else "-"

        line = (f"{row['Enlace']:>15}"
                f"  {cv_s:>{ancho_car}}  {pr_s:>{ancho_car}}  {p99_s:>{ancho_car}}")
        for m in cols_modelo:
            val = row.get(f"{metrica}_{m}")
            line += f"  {f'{val:.2e}' if pd.notna(val) else '-':>{ancho}}"
        line += f"  {row.get(f'mejor_{metrica}', '-'):>{ancho}}"
        print(line)

    print("-" * len(header))
    row_g = df[df["Enlace"] == "── GLOBAL ──"].iloc[0]
    line  = f"{'── GLOBAL ──':>15}  {'':>{ancho_car}}  {'':>{ancho_car}}  {'':>{ancho_car}}"
    for m in cols_modelo:
        val = row_g.get(f"{metrica}_{m}")
        line += f"  {f'{val:.2e}' if pd.notna(val) else '-':>{ancho}}"
    line += f"  {row_g.get(f'mejor_{metrica}', '-'):>{ancho}}"
    print(line)

    df_s = df[df["Enlace"] != "── GLOBAL ──"]
    col_mejor = f"mejor_{metrica}"
    if col_mejor in df_s.columns:
        print(f"\n🏆 VICTORIAS ({metrica}):")
        for modelo, n in df_s[col_mejor].value_counts().items():
            print(f"   {modelo}: {n}/{len(df_s)} ({100*n/len(df_s):.1f}%)")


def construir_tabla_enlaces(datos, cols_modelo, caract, metricas=("MAE", "RMSE", "MAPE")):
    todos_enlaces = sorted(set(e for res in datos.values() for e in res))
    filas = []
    for enlace in todos_enlaces:
        fila = {"Enlace": enlace}

        # ── Caracterización ──────────────────────────────────
        info = caract.get(enlace, {})
        fila["CV%"]       = info.get("CV%")
        fila["PicoRatio"] = info.get("PicoRatio")
        fila["P99"]       = info.get("P99")

        for m in cols_modelo:
            if enlace in datos.get(m, {}):
                for met in metricas:
                    fila[f"{met}_{m}"] = datos[m][enlace][met]
                fila[f"N_{m}"] = datos[m][enlace]["N"]
            else:
                for met in metricas:
                    fila[f"{met}_{m}"] = None
                fila[f"N_{m}"] = 0
        filas.append(fila)

    df = pd.DataFrame(filas)

    for met in metricas:
        cols_met = [f"{met}_{m}" for m in cols_modelo if f"{met}_{m}" in df.columns]
        if cols_met:
            df[f"mejor_{met}"] = df[cols_met].idxmin(axis=1).str.replace(f"{met}_", "", regex=False)

    fila_g = {"Enlace": "── GLOBAL ──"}
    for met in metricas:
        g = fila_global(df, cols_modelo, met)
        for k, v in g.items():
            if k != "Enlace":
                fila_g[k] = v

    df = pd.concat([df, pd.DataFrame([fila_g])], ignore_index=True)
    return df


def comparar():
    # Calcular caracterización una sola vez (mismo dataset para todos)
    etiq_base, carp_rel, pref, suf = FUENTES_BASELINE[0]
    print("📊 Calculando caracterización de enlaces...")
    caract = caracterizar_enlaces(carp_rel, pref, suf, trigger=TRIGGER)
    print(f"   {len(caract)} enlaces caracterizados")

    grupos = {}
    for nombre in sorted(os.listdir(ROOT_RESULTS)):
        m = PATRON_ARQ.match(nombre)
        if not m:
            continue
        arq_id, h_m, modo, w, p, h2 = m.group(1), m.group(2), m.group(3), m.group(4), m.group(5), m.group(6)
        horizonte = int(h_m)
        ventana   = int(w)
        peso      = int(p)
        etiqueta  = f"Arq{arq_id}_{modo}"

        clave = (ventana, horizonte, peso)
        if clave not in grupos:
            grupos[clave] = {}

        carpeta_abs     = os.path.join(ROOT_RESULTS, nombre)
        prefijo_fichero = f"test_Arq{arq_id}_{h_m}m_{modo}_W{w}_p{p}_H{h2}_"
        print(f"📂 Leyendo {nombre}  →  {etiqueta}")
        grupos[clave][etiqueta] = leer_carpeta_arq(carpeta_abs, prefijo_fichero)
        print(f"   {len(grupos[clave][etiqueta])} enlaces")

    if not grupos:
        print("❌ No se encontraron carpetas results_Arq*_*m_[AB]_W*_p*_H*")
        return

    todos_dfs = []

    for (ventana, horizonte, peso), datos_arq in sorted(grupos.items()):
        print(f"\n{'#'*60}")
        print(f"  W={ventana} | H={horizonte}min | peso={int(peso)/100:.2f}  —  {len(datos_arq)} configs")
        print(f"{'#'*60}")

        datos_all = dict(datos_arq)
        for etiq, carp_rel, pref, suf in FUENTES_BASELINE:
            datos_all[etiq] = leer_baseline(etiq, carp_rel, pref, suf, horizonte)

        cols_baselines = [e for e, *_ in FUENTES_BASELINE]
        cols_modelo    = ordenar_columnas_modelo(cols_baselines + list(datos_arq.keys()))
        df_tabla       = construir_tabla_enlaces(datos_all, cols_modelo, caract)

        for metrica in ["MAE", "RMSE", "MAPE"]:
            imprimir_tabla(df_tabla, metrica, cols_modelo, horizonte, ventana, peso, TRIGGER)

        nombre_out = f"Results_min/comparativa_W{ventana}_H{horizonte}_p{str(peso).zfill(2)}.csv"
        df_tabla[df_tabla["Enlace"] != "── GLOBAL ──"].to_csv(nombre_out, index=False)
        print(f"\n💾 {nombre_out}")
        todos_dfs.append(df_tabla.assign(W=ventana, H=horizonte, peso=peso))

    if todos_dfs:
        pd.concat(todos_dfs, ignore_index=True).to_csv(OUTPUT_CSV, index=False)
        print(f"\n💾 CSV global: {OUTPUT_CSV}")


if __name__ == "__main__":
    comparar()
# Out:
# 📊 Calculando caracterización de enlaces...
#    81 enlaces caracterizados
# 📂 Leyendo results_Arq1_15m_A_W60_p00_H15  →  Arq1_A
#    81 enlaces
# 📂 Leyendo results_Arq1_15m_A_W60_p25_H15  →  Arq1_A
#    81 enlaces
# 📂 Leyendo results_Arq1_15m_A_W60_p50_H15  →  Arq1_A
#    81 enlaces
# 📂 Leyendo results_Arq1_15m_A_W60_p75_H15  →  Arq1_A
#    81 enlaces
# 📂 Leyendo results_Arq1_15m_B_W60_p00_H15  →  Arq1_B
#    81 enlaces
# 📂 Leyendo results_Arq1_15m_B_W60_p25_H15  →  Arq1_B
#    81 enlaces
# 📂 Leyendo results_Arq1_15m_B_W60_p50_H15  →  Arq1_B
#    81 enlaces
# 📂 Leyendo results_Arq1_15m_B_W60_p75_H15  →  Arq1_B
#    81 enlaces
# 📂 Leyendo results_Arq1_5m_A_W60_p00_H5  →  Arq1_A
#    81 enlaces
# 📂 Leyendo results_Arq1_5m_A_W60_p25_H5  →  Arq1_A
#    81 enlaces
# 📂 Leyendo results_Arq1_5m_A_W60_p50_H5  →  Arq1_A
#    81 enlaces
# 📂 Leyendo results_Arq1_5m_A_W60_p75_H5  →  Arq1_A
#    81 enlaces
# 📂 Leyendo results_Arq1_5m_B_W60_p00_H5  →  Arq1_B
#    81 enlaces
# 📂 Leyendo results_Arq1_5m_B_W60_p25_H5  →  Arq1_B
#    81 enlaces
# 📂 Leyendo results_Arq1_5m_B_W60_p50_H5  →  Arq1_B
#    81 enlaces
# 📂 Leyendo results_Arq1_5m_B_W60_p75_H5  →  Arq1_B
#    81 enlaces
# 📂 Leyendo results_Arq2_15m_A_W60_p00_H15  →  Arq2_A
#    81 enlaces
# 📂 Leyendo results_Arq2_15m_A_W60_p25_H15  →  Arq2_A
#    81 enlaces
# 📂 Leyendo results_Arq2_15m_A_W60_p50_H15  →  Arq2_A
#    81 enlaces
# 📂 Leyendo results_Arq2_15m_A_W60_p75_H15  →  Arq2_A
#    81 enlaces
# 📂 Leyendo results_Arq2_15m_B_W60_p00_H15  →  Arq2_B
#    81 enlaces
# 📂 Leyendo results_Arq2_15m_B_W60_p25_H15  →  Arq2_B
#    81 enlaces
# 📂 Leyendo results_Arq2_15m_B_W60_p50_H15  →  Arq2_B
#    81 enlaces
# 📂 Leyendo results_Arq2_15m_B_W60_p75_H15  →  Arq2_B
#    81 enlaces
# 📂 Leyendo results_Arq2_5m_A_W60_p00_H5  →  Arq2_A
#    81 enlaces
# 📂 Leyendo results_Arq2_5m_A_W60_p25_H5  →  Arq2_A
#    81 enlaces
# 📂 Leyendo results_Arq2_5m_A_W60_p50_H5  →  Arq2_A
#    81 enlaces
# 📂 Leyendo results_Arq2_5m_A_W60_p75_H5  →  Arq2_A
#    81 enlaces
# 📂 Leyendo results_Arq2_5m_B_W60_p00_H5  →  Arq2_B
#    81 enlaces
# 📂 Leyendo results_Arq2_5m_B_W60_p25_H5  →  Arq2_B
#    81 enlaces
# 📂 Leyendo results_Arq2_5m_B_W60_p50_H5  →  Arq2_B
#    81 enlaces
# 📂 Leyendo results_Arq2_5m_B_W60_p75_H5  →  Arq2_B
#    81 enlaces
# 📂 Leyendo results_Arq3_15m_A_W60_p00_H15  →  Arq3_A
#    81 enlaces
# 📂 Leyendo results_Arq3_15m_A_W60_p25_H15  →  Arq3_A
#    81 enlaces
# 📂 Leyendo results_Arq3_15m_A_W60_p50_H15  →  Arq3_A
#    81 enlaces
# 📂 Leyendo results_Arq3_15m_A_W60_p75_H15  →  Arq3_A
#    81 enlaces
# 📂 Leyendo results_Arq3_15m_B_W60_p00_H15  →  Arq3_B
#    81 enlaces
# 📂 Leyendo results_Arq3_15m_B_W60_p25_H15  →  Arq3_B
#    81 enlaces
# 📂 Leyendo results_Arq3_15m_B_W60_p50_H15  →  Arq3_B
#    81 enlaces
# 📂 Leyendo results_Arq3_15m_B_W60_p75_H15  →  Arq3_B
#    81 enlaces
# 📂 Leyendo results_Arq3_5m_A_W60_p00_H5  →  Arq3_A
#    81 enlaces
# 📂 Leyendo results_Arq3_5m_A_W60_p25_H5  →  Arq3_A
#    81 enlaces
# 📂 Leyendo results_Arq3_5m_A_W60_p50_H5  →  Arq3_A
#    81 enlaces
# 📂 Leyendo results_Arq3_5m_A_W60_p75_H5  →  Arq3_A
#    81 enlaces
# 📂 Leyendo results_Arq3_5m_B_W60_p00_H5  →  Arq3_B
#    81 enlaces
# 📂 Leyendo results_Arq3_5m_B_W60_p25_H5  →  Arq3_B
#    81 enlaces
# 📂 Leyendo results_Arq3_5m_B_W60_p50_H5  →  Arq3_B
#    81 enlaces
# 📂 Leyendo results_Arq3_5m_B_W60_p75_H5  →  Arq3_B
#    81 enlaces
# 📂 Leyendo results_Arq4_15m_A_W60_p00_H15  →  Arq4_A
#    81 enlaces
# 📂 Leyendo results_Arq4_15m_A_W60_p25_H15  →  Arq4_A
#    81 enlaces
# 📂 Leyendo results_Arq4_15m_A_W60_p50_H15  →  Arq4_A
#    81 enlaces
# 📂 Leyendo results_Arq4_15m_A_W60_p75_H15  →  Arq4_A
#    81 enlaces
# 📂 Leyendo results_Arq4_15m_B_W60_p00_H15  →  Arq4_B
#    81 enlaces
# 📂 Leyendo results_Arq4_15m_B_W60_p25_H15  →  Arq4_B
#    81 enlaces
# 📂 Leyendo results_Arq4_15m_B_W60_p50_H15  →  Arq4_B
#    81 enlaces
# 📂 Leyendo results_Arq4_15m_B_W60_p75_H15  →  Arq4_B
#    81 enlaces
# 📂 Leyendo results_Arq4_5m_A_W60_p00_H5  →  Arq4_A
#    81 enlaces
# 📂 Leyendo results_Arq4_5m_A_W60_p25_H5  →  Arq4_A
#    81 enlaces
# 📂 Leyendo results_Arq4_5m_A_W60_p50_H5  →  Arq4_A
#    81 enlaces
# 📂 Leyendo results_Arq4_5m_A_W60_p75_H5  →  Arq4_A
#    81 enlaces
# 📂 Leyendo results_Arq4_5m_B_W60_p00_H5  →  Arq4_B
#    81 enlaces
# 📂 Leyendo results_Arq4_5m_B_W60_p25_H5  →  Arq4_B
#    81 enlaces
# 📂 Leyendo results_Arq4_5m_B_W60_p50_H5  →  Arq4_B
#    81 enlaces
# 📂 Leyendo results_Arq4_5m_B_W60_p75_H5  →  Arq4_B
#    81 enlaces
#
# ############################################################
#   W=60 | H=5min | peso=0.00  —  8 configs
# ############################################################
#
# ============================================================================================================================================
#  MAE — t+5min | W=60 | peso=0.00 | Realidad > 1,000
# ============================================================================================================================================
#          Enlace         CV%   PicoRatio         P99           ARIMA           Naive          Arq1_A          Arq1_B          Arq2_A          Arq2_B          Arq3_A          Arq3_B          Arq4_A          Arq4_B           mejor
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#         ADH_ADH       111.7        10.4    2.01e+07        2.22e+06        2.62e+06        2.52e+06        3.70e+06        2.55e+06        3.70e+06        2.52e+06        3.64e+06        2.51e+06        3.71e+06           ARIMA
#         ADH_CVK       112.2         8.1    5.13e+05        3.93e+04        4.34e+04        4.42e+04        6.69e+04        4.32e+04        7.10e+04        4.30e+04        6.40e+04        4.31e+04        6.63e+04           ARIMA
#         ADH_HTW        88.0         5.0    1.63e+07        1.39e+06        1.64e+06        1.72e+06        4.95e+06        1.71e+06        4.89e+06        1.77e+06        4.94e+06        1.72e+06        5.07e+06           ARIMA
#        ZIB_WIAS       139.4        12.0    4.95e+06        1.93e+02        1.75e+02        1.95e+02        9.39e+01        2.05e+02        9.57e+01        1.83e+02        9.53e+01        1.84e+02        9.43e+01          Arq1_B
#         ZIB_ZIB       103.4         6.6    1.15e+08        9.73e+01        9.75e+01        1.06e+02        8.78e+01        1.06e+02        9.07e+01        8.58e+01        9.02e+01        1.07e+02        8.89e+01          Arq3_A
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    ── GLOBAL ──                                            2.32e+02        2.20e+02        2.59e+02        1.27e+02        2.57e+02        1.22e+02        2.86e+02        1.22e+02        2.40e+02        9.79e+01          Arq4_B
#
# 🏆 VICTORIAS (MAPE):
#    Arq1_B: 25/81 (30.9%)
#    ARIMA: 22/81 (27.2%)
#    Arq3_B: 10/81 (12.3%)
#    Arq4_B: 9/81 (11.1%)
#    Arq2_B: 7/81 (8.6%)
#    Naive: 3/81 (3.7%)
#    Arq1_A: 3/81 (3.7%)
#    Arq2_A: 1/81 (1.2%)
#    Arq3_A: 1/81 (1.2%)
#
# 💾 Results_min/comparativa_W60_H15_p75.csv
#
# 💾 CSV global: Results_min/comparativa_arq.csv

# %%
import os
import re
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# ============================================================
# CONFIGURACIÓN
# ============================================================
ROOT_RESULTS = "Results_min"
COL_REAL     = "Realidad"
COL_PRED     = "Prediccion"
TRIGGER      = 1000

FUENTES_BASELINE = [
    ("ARIMA", "results_baselines_1min", "test_results_", "_baselines.csv"),
    ("Naive", "results_baselines_1min", "test_results_", "_baselines.csv"),
]
# ============================================================

PATRON_ARQ = re.compile(
    r"^results_Arq(\d+)_(\d+)m_([AB])_W(\d+)_p(\d+)_H(\d+)$"
)


def mape(y_real, y_pred):
    mask = y_real > 1e-6
    return np.mean(np.abs((y_real[mask] - y_pred[mask]) / y_real[mask])) * 100 if mask.sum() > 0 else np.nan


def calcular_metricas(y_real, y_pred, trigger=None):
    mask_nan = ~(np.isnan(y_real) | np.isnan(y_pred))
    y_real, y_pred = y_real[mask_nan], y_pred[mask_nan]
    if trigger is not None:
        m = y_real > trigger
        y_real, y_pred = y_real[m], y_pred[m]
    if len(y_real) == 0:
        return None, None, None, 0
    mae  = mean_absolute_error(y_real, y_pred)
    rmse = np.sqrt(mean_squared_error(y_real, y_pred))
    mp   = mape(y_real, y_pred)
    return round(mae, 2), round(rmse, 2), round(mp, 2), len(y_real)


def es_enlace_valido(enlace):
    partes = enlace.split("_")
    return len(partes) == 2 and all(len(p) >= 2 for p in partes)


def leer_carpeta_arq(carpeta_abs, prefijo):
    resultados = {}
    if not os.path.exists(carpeta_abs):
        return resultados
    for f in sorted(os.listdir(carpeta_abs)):
        if not f.startswith(prefijo) or not f.endswith(".csv"):
            continue
        enlace = f[len(prefijo):-4]
        if not enlace or not es_enlace_valido(enlace):
            continue
        try:
            df = pd.read_csv(os.path.join(carpeta_abs, f))
            if COL_REAL not in df.columns or COL_PRED not in df.columns:
                continue
            y_real = df[COL_REAL].values.astype(float)
            y_pred = df[COL_PRED].values.astype(float)
            mae, rmse, mp, n = calcular_metricas(y_real, y_pred, TRIGGER)
            if mae is not None:
                resultados[enlace] = {"MAE": mae, "RMSE": rmse, "MAPE": mp, "N": n}
        except Exception as e:
            print(f"   ❌ {f}: {e}")
    return resultados


def leer_baseline(etiqueta, carpeta_rel, prefijo, sufijo, horizonte):
    col = f"{etiqueta}_t+{horizonte}"
    carpeta_abs = os.path.join(ROOT_RESULTS, carpeta_rel)
    resultados = {}
    if not os.path.exists(carpeta_abs):
        return resultados
    for f in sorted(os.listdir(carpeta_abs)):
        if not f.startswith(prefijo) or not f.endswith(sufijo):
            continue
        enlace = f[len(prefijo): len(f) - len(sufijo)]
        if not enlace or not es_enlace_valido(enlace):
            continue
        try:
            df = pd.read_csv(os.path.join(carpeta_abs, f))
            if COL_REAL not in df.columns or col not in df.columns:
                continue
            y_real = df[COL_REAL].values.astype(float)
            y_pred = df[col].values.astype(float)
            mae, rmse, mp, n = calcular_metricas(y_real, y_pred, TRIGGER)
            if mae is not None:
                resultados[enlace] = {"MAE": mae, "RMSE": rmse, "MAPE": mp, "N": n}
        except Exception as e:
            print(f"   ❌ {f}: {e}")
    return resultados


def construir_tabla_enlaces(datos, cols_modelo, metricas=("MAE", "RMSE", "MAPE")):
    todos_enlaces = sorted(set(e for res in datos.values() for e in res))
    filas = []
    for enlace in todos_enlaces:
        fila = {"Enlace": enlace}
        for m in cols_modelo:
            if enlace in datos.get(m, {}):
                for met in metricas:
                    fila[f"{met}_{m}"] = datos[m][enlace][met]
            else:
                for met in metricas:
                    fila[f"{met}_{m}"] = None
        filas.append(fila)
    return pd.DataFrame(filas)


def ordenar_columnas_modelo(cols_modelo):
    baselines_orden = ["ARIMA", "Naive"]
    baselines = [c for c in baselines_orden if c in cols_modelo]
    arq_cols  = [c for c in cols_modelo if c not in baselines_orden]

    def sort_key(etiq):
        m = re.match(r"Arq(\d+)_([AB])", etiq)
        if m:
            return (int(m.group(1)), 0 if m.group(2) == "A" else 1)
        return (99, 99)

    return baselines + sorted(arq_cols, key=sort_key)


def imprimir_1v1(df, cols_modelo, ventana, horizonte, peso, filas_csv):
    baselines   = ["ARIMA", "Naive"]
    modelos_arq = [m for m in cols_modelo if m not in baselines]
    metricas    = ["MAE", "RMSE", "MAPE"]
    ancho       = 11
    peso_fmt    = f"{int(peso)/100:.2f}"

    for baseline in baselines:
        print(f"\n{'='*90}")
        print(f"  1 vs 1  ──  {baseline}  |  W={ventana} | H={horizonte}min | peso={peso_fmt}")
        print(f"{'='*90}")

        cabecera = f"{'Modelo':>16}"
        for met in metricas:
            cabecera += f"  {(met+' Gana'):>{ancho}}  {(met+' Pierde'):>{ancho}}  {(met+' %Win'):>{ancho}}"
        print(cabecera)
        print("-" * len(cabecera))

        for modelo in modelos_arq:
            line     = f"{modelo:>16}"
            fila_csv = {"W": ventana, "H": horizonte, "peso": peso_fmt,
                        "Baseline": baseline, "Modelo": modelo}

            for met in metricas:
                col_mod  = f"{met}_{modelo}"
                col_base = f"{met}_{baseline}"
                if col_mod not in df.columns or col_base not in df.columns:
                    line += f"  {'?':>{ancho}}  {'?':>{ancho}}  {'?':>{ancho}}"
                    fila_csv[f"{met}_Gana"]   = None
                    fila_csv[f"{met}_Pierde"] = None
                    fila_csv[f"{met}_Total"]  = None
                    fila_csv[f"{met}_Pct"]    = None
                    continue

                sub    = df[[col_mod, col_base]].dropna()
                total  = len(sub)
                gana   = int((sub[col_mod] < sub[col_base]).sum())
                pierde = int((sub[col_mod] > sub[col_base]).sum())
                pct    = round(100 * gana / total, 1) if total > 0 else 0.0

                line += f"  {f'{gana}/{total}':>{ancho}}  {f'{pierde}/{total}':>{ancho}}  {f'{pct}%':>{ancho}}"
                fila_csv[f"{met}_Gana"]   = gana
                fila_csv[f"{met}_Pierde"] = pierde
                fila_csv[f"{met}_Total"]  = total
                fila_csv[f"{met}_Pct"]    = pct

            print(line)
            filas_csv.append(fila_csv)

        print(f"\n  G = modelo < {baseline}  |  P = modelo > {baseline}  |  % = victorias sobre {len(df)} enlaces")


def comparar():
    grupos = {}

    for nombre in sorted(os.listdir(ROOT_RESULTS)):
        m = PATRON_ARQ.match(nombre)
        if not m:
            continue
        arq_id = m.group(1)
        h_m    = m.group(2)
        modo   = m.group(3)
        w      = m.group(4)
        p      = m.group(5)
        h2     = m.group(6)

        horizonte = int(h_m)
        ventana   = int(w)
        peso      = int(p)
        etiqueta  = f"Arq{arq_id}_{modo}"

        clave = (ventana, horizonte, peso)
        if clave not in grupos:
            grupos[clave] = {}

        carpeta_abs     = os.path.join(ROOT_RESULTS, nombre)
        prefijo_fichero = f"test_Arq{arq_id}_{h_m}m_{modo}_W{w}_p{p}_H{h2}_"
        print(f"📂 {nombre}  →  {etiqueta}")
        grupos[clave][etiqueta] = leer_carpeta_arq(carpeta_abs, prefijo_fichero)
        print(f"   {len(grupos[clave][etiqueta])} enlaces")

    if not grupos:
        print("❌ No se encontraron carpetas results_Arq*_*m_[AB]_W*_p*_H*")
        return

    filas_csv = []

    for (ventana, horizonte, peso), datos_arq in sorted(grupos.items()):
        print(f"\n{'#'*60}")
        print(f"  W={ventana} | H={horizonte}min | peso={int(peso)/100:.2f}  —  {len(datos_arq)} modelos")
        print(f"{'#'*60}")

        datos_all = dict(datos_arq)
        for etiq, carp_rel, pref, suf in FUENTES_BASELINE:
            datos_all[etiq] = leer_baseline(etiq, carp_rel, pref, suf, horizonte)

        cols_baselines = [e for e, *_ in FUENTES_BASELINE]
        cols_modelo    = ordenar_columnas_modelo(cols_baselines + list(datos_arq.keys()))
        df_tabla       = construir_tabla_enlaces(datos_all, cols_modelo)

        imprimir_1v1(df_tabla, cols_modelo, ventana, horizonte, peso, filas_csv)

    if filas_csv:
        df_out = pd.DataFrame(filas_csv)
        salida = f"{ROOT_RESULTS}/1v1_resumen_min.csv"
        df_out.to_csv(salida, index=False)
        print(f"\n💾 CSV guardado: {salida}")


if __name__ == "__main__":
    comparar()
# Out:
# 📂 results_Arq1_15m_A_W60_p00_H15  →  Arq1_A
#    81 enlaces
# 📂 results_Arq1_15m_A_W60_p25_H15  →  Arq1_A
#    81 enlaces
# 📂 results_Arq1_15m_A_W60_p50_H15  →  Arq1_A
#    81 enlaces
# 📂 results_Arq1_15m_A_W60_p75_H15  →  Arq1_A
#    81 enlaces
# 📂 results_Arq1_15m_B_W60_p00_H15  →  Arq1_B
#    81 enlaces
# 📂 results_Arq1_15m_B_W60_p25_H15  →  Arq1_B
#    81 enlaces
# 📂 results_Arq1_15m_B_W60_p50_H15  →  Arq1_B
#    81 enlaces
# 📂 results_Arq1_15m_B_W60_p75_H15  →  Arq1_B
#    81 enlaces
# 📂 results_Arq1_5m_A_W60_p00_H5  →  Arq1_A
#    81 enlaces
# 📂 results_Arq1_5m_A_W60_p25_H5  →  Arq1_A
#    81 enlaces
# 📂 results_Arq1_5m_A_W60_p50_H5  →  Arq1_A
#    81 enlaces
# 📂 results_Arq1_5m_A_W60_p75_H5  →  Arq1_A
#    81 enlaces
# 📂 results_Arq1_5m_B_W60_p00_H5  →  Arq1_B
#    81 enlaces
# 📂 results_Arq1_5m_B_W60_p25_H5  →  Arq1_B
#    81 enlaces
# 📂 results_Arq1_5m_B_W60_p50_H5  →  Arq1_B
#    81 enlaces
# 📂 results_Arq1_5m_B_W60_p75_H5  →  Arq1_B
#    81 enlaces
# 📂 results_Arq2_15m_A_W60_p00_H15  →  Arq2_A
#    81 enlaces
# 📂 results_Arq2_15m_A_W60_p25_H15  →  Arq2_A
#    81 enlaces
# 📂 results_Arq2_15m_A_W60_p50_H15  →  Arq2_A
#    81 enlaces
# 📂 results_Arq2_15m_A_W60_p75_H15  →  Arq2_A
#    81 enlaces
# 📂 results_Arq2_15m_B_W60_p00_H15  →  Arq2_B
#    81 enlaces
# 📂 results_Arq2_15m_B_W60_p25_H15  →  Arq2_B
#    81 enlaces
# 📂 results_Arq2_15m_B_W60_p50_H15  →  Arq2_B
#    81 enlaces
# 📂 results_Arq2_15m_B_W60_p75_H15  →  Arq2_B
#    81 enlaces
# 📂 results_Arq2_5m_A_W60_p00_H5  →  Arq2_A
#    81 enlaces
# 📂 results_Arq2_5m_A_W60_p25_H5  →  Arq2_A
#    81 enlaces
# 📂 results_Arq2_5m_A_W60_p50_H5  →  Arq2_A
#    81 enlaces
# 📂 results_Arq2_5m_A_W60_p75_H5  →  Arq2_A
#    81 enlaces
# 📂 results_Arq2_5m_B_W60_p00_H5  →  Arq2_B
#    81 enlaces
# 📂 results_Arq2_5m_B_W60_p25_H5  →  Arq2_B
#    81 enlaces
# 📂 results_Arq2_5m_B_W60_p50_H5  →  Arq2_B
#    81 enlaces
# 📂 results_Arq2_5m_B_W60_p75_H5  →  Arq2_B
#    81 enlaces
# 📂 results_Arq3_15m_A_W60_p00_H15  →  Arq3_A
#    81 enlaces
# 📂 results_Arq3_15m_A_W60_p25_H15  →  Arq3_A
#    81 enlaces
# 📂 results_Arq3_15m_A_W60_p50_H15  →  Arq3_A
#    81 enlaces
# 📂 results_Arq3_15m_A_W60_p75_H15  →  Arq3_A
#    81 enlaces
# 📂 results_Arq3_15m_B_W60_p00_H15  →  Arq3_B
#    81 enlaces
# 📂 results_Arq3_15m_B_W60_p25_H15  →  Arq3_B
#    81 enlaces
# 📂 results_Arq3_15m_B_W60_p50_H15  →  Arq3_B
#    81 enlaces
# 📂 results_Arq3_15m_B_W60_p75_H15  →  Arq3_B
#    81 enlaces
# 📂 results_Arq3_5m_A_W60_p00_H5  →  Arq3_A
#    81 enlaces
# 📂 results_Arq3_5m_A_W60_p25_H5  →  Arq3_A
#    81 enlaces
# 📂 results_Arq3_5m_A_W60_p50_H5  →  Arq3_A
#    81 enlaces
# 📂 results_Arq3_5m_A_W60_p75_H5  →  Arq3_A
#    81 enlaces
# 📂 results_Arq3_5m_B_W60_p00_H5  →  Arq3_B
#    81 enlaces
# 📂 results_Arq3_5m_B_W60_p25_H5  →  Arq3_B
#    81 enlaces
# 📂 results_Arq3_5m_B_W60_p50_H5  →  Arq3_B
#    81 enlaces
# 📂 results_Arq3_5m_B_W60_p75_H5  →  Arq3_B
#    81 enlaces
# 📂 results_Arq4_15m_A_W60_p00_H15  →  Arq4_A
#    81 enlaces
# 📂 results_Arq4_15m_A_W60_p25_H15  →  Arq4_A
#    81 enlaces
# 📂 results_Arq4_15m_A_W60_p50_H15  →  Arq4_A
#    81 enlaces
# 📂 results_Arq4_15m_A_W60_p75_H15  →  Arq4_A
#    81 enlaces
# 📂 results_Arq4_15m_B_W60_p00_H15  →  Arq4_B
#    81 enlaces
# 📂 results_Arq4_15m_B_W60_p25_H15  →  Arq4_B
#    81 enlaces
# 📂 results_Arq4_15m_B_W60_p50_H15  →  Arq4_B
#    81 enlaces
# 📂 results_Arq4_15m_B_W60_p75_H15  →  Arq4_B
#    81 enlaces
# 📂 results_Arq4_5m_A_W60_p00_H5  →  Arq4_A
#    81 enlaces
# 📂 results_Arq4_5m_A_W60_p25_H5  →  Arq4_A
#    81 enlaces
# 📂 results_Arq4_5m_A_W60_p50_H5  →  Arq4_A
#    81 enlaces
# 📂 results_Arq4_5m_A_W60_p75_H5  →  Arq4_A
#    81 enlaces
# 📂 results_Arq4_5m_B_W60_p00_H5  →  Arq4_B
#    81 enlaces
# 📂 results_Arq4_5m_B_W60_p25_H5  →  Arq4_B
#    81 enlaces
# 📂 results_Arq4_5m_B_W60_p50_H5  →  Arq4_B
#    81 enlaces
# 📂 results_Arq4_5m_B_W60_p75_H5  →  Arq4_B
#    81 enlaces
#
# ############################################################
#   W=60 | H=5min | peso=0.00  —  8 modelos
# ############################################################
#
# ==========================================================================================
#   1 vs 1  ──  ARIMA  |  W=60 | H=5min | peso=0.00
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        19/81        62/81        23.5%        19/81        62/81        23.5%        47/81        34/81        58.0%
#           Arq1_B        30/81        51/81        37.0%        29/81        52/81        35.8%        64/81        17/81        79.0%
#           Arq2_A        20/81        61/81        24.7%        22/81        59/81        27.2%        51/81        30/81        63.0%
#           Arq2_B        30/81        51/81        37.0%        33/81        48/81        40.7%        65/81        16/81        80.2%
#           Arq3_A        20/81        61/81        24.7%        23/81        58/81        28.4%        48/81        33/81        59.3%
#           Arq3_B        23/81        58/81        28.4%        30/81        51/81        37.0%        66/81        15/81        81.5%
#           Arq4_A        21/81        60/81        25.9%        19/81        62/81        23.5%        49/81        32/81        60.5%
#           Arq4_B        27/81        54/81        33.3%        24/81        57/81        29.6%        64/81        17/81        79.0%
#
#   G = modelo < ARIMA  |  P = modelo > ARIMA  |  % = victorias sobre 81 enlaces
#
# ==========================================================================================
#   1 vs 1  ──  Naive  |  W=60 | H=5min | peso=0.00
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        57/81        24/81        70.4%        52/81        29/81        64.2%        62/81        19/81        76.5%
#           Arq1_B        39/81        42/81        48.1%        43/81        38/81        53.1%        68/81        13/81        84.0%
#           Arq2_A        68/81        13/81        84.0%        63/81        18/81        77.8%        71/81        10/81        87.7%
#           Arq2_B        40/81        41/81        49.4%        46/81        35/81        56.8%        66/81        15/81        81.5%
#           Arq3_A        65/81        16/81        80.2%        60/81        21/81        74.1%        65/81        16/81        80.2%
#           Arq3_B        31/81        50/81        38.3%        43/81        38/81        53.1%        66/81        15/81        81.5%
#           Arq4_A        63/81        18/81        77.8%        62/81        19/81        76.5%        66/81        14/81        81.5%
#           Arq4_B        34/81        47/81        42.0%        40/81        41/81        49.4%        65/81        16/81        80.2%
#
#   G = modelo < Naive  |  P = modelo > Naive  |  % = victorias sobre 81 enlaces
#
# ############################################################
#   W=60 | H=5min | peso=0.25  —  8 modelos
# ############################################################
#
# ==========================================================================================
#   1 vs 1  ──  ARIMA  |  W=60 | H=5min | peso=0.25
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        16/81        65/81        19.8%        24/81        57/81        29.6%        37/81        44/81        45.7%
#           Arq1_B         7/81        74/81         8.6%        14/81        67/81        17.3%        62/81        19/81        76.5%
#           Arq2_A        13/81        68/81        16.0%        20/81        61/81        24.7%        37/81        44/81        45.7%
#           Arq2_B         7/81        74/81         8.6%        14/81        67/81        17.3%        59/81        22/81        72.8%
#           Arq3_A        17/81        64/81        21.0%        22/81        59/81        27.2%        38/81        43/81        46.9%
#           Arq3_B         7/81        74/81         8.6%        11/81        70/81        13.6%        58/81        23/81        71.6%
#           Arq4_A        11/81        70/81        13.6%        15/81        66/81        18.5%        31/81        50/81        38.3%
#           Arq4_B         7/81        74/81         8.6%        11/81        70/81        13.6%        59/81        22/81        72.8%
#
#   G = modelo < ARIMA  |  P = modelo > ARIMA  |  % = victorias sobre 81 enlaces
#
# ==========================================================================================
#   1 vs 1  ──  Naive  |  W=60 | H=5min | peso=0.25
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        35/81        46/81        43.2%        45/81        36/81        55.6%        38/81        43/81        46.9%
#           Arq1_B        13/81        68/81        16.0%        22/81        59/81        27.2%        66/81        15/81        81.5%
#           Arq2_A        37/81        44/81        45.7%        45/81        36/81        55.6%        37/81        44/81        45.7%
#           Arq2_B        13/81        68/81        16.0%        18/81        63/81        22.2%        62/81        19/81        76.5%
#           Arq3_A        42/81        39/81        51.9%        50/81        31/81        61.7%        41/81        40/81        50.6%
#           Arq3_B        12/81        69/81        14.8%        21/81        60/81        25.9%        59/81        22/81        72.8%
#           Arq4_A        31/81        50/81        38.3%        37/81        44/81        45.7%        35/81        46/81        43.2%
#           Arq4_B        11/81        70/81        13.6%        19/81        62/81        23.5%        61/81        20/81        75.3%
#
#   G = modelo < Naive  |  P = modelo > Naive  |  % = victorias sobre 81 enlaces
#
# ############################################################
#   W=60 | H=5min | peso=0.50  —  8 modelos
# ############################################################
#
# ==========================================================================================
#   1 vs 1  ──  ARIMA  |  W=60 | H=5min | peso=0.50
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        13/81        68/81        16.0%        19/81        62/81        23.5%        30/81        51/81        37.0%
#           Arq1_B         2/81        79/81         2.5%         5/81        76/81         6.2%        44/81        37/81        54.3%
#           Arq2_A        13/81        68/81        16.0%        21/81        60/81        25.9%        33/81        48/81        40.7%
#           Arq2_B         2/81        79/81         2.5%         5/81        76/81         6.2%        42/81        39/81        51.9%
#           Arq3_A        12/81        69/81        14.8%        16/81        65/81        19.8%        32/81        49/81        39.5%
#           Arq3_B         2/81        79/81         2.5%         5/81        76/81         6.2%        41/81        40/81        50.6%
#           Arq4_A         9/81        72/81        11.1%        15/81        66/81        18.5%        27/81        54/81        33.3%
#           Arq4_B         2/81        79/81         2.5%         5/81        76/81         6.2%        42/81        39/81        51.9%
#
#   G = modelo < ARIMA  |  P = modelo > ARIMA  |  % = victorias sobre 81 enlaces
#
# ==========================================================================================
#   1 vs 1  ──  Naive  |  W=60 | H=5min | peso=0.50
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        31/81        50/81        38.3%        43/81        38/81        53.1%        31/81        50/81        38.3%
#           Arq1_B         3/81        78/81         3.7%         9/81        72/81        11.1%        44/81        37/81        54.3%
#           Arq2_A        30/81        51/81        37.0%        41/81        40/81        50.6%        27/81        54/81        33.3%
#           Arq2_B         2/81        79/81         2.5%         9/81        72/81        11.1%        42/81        39/81        51.9%
#           Arq3_A        32/81        49/81        39.5%        40/81        41/81        49.4%        31/81        50/81        38.3%
#           Arq3_B         2/81        79/81         2.5%         9/81        72/81        11.1%        42/81        39/81        51.9%
#           Arq4_A        25/81        56/81        30.9%        33/81        48/81        40.7%        28/81        53/81        34.6%
#           Arq4_B         2/81        79/81         2.5%         9/81        72/81        11.1%        41/81        40/81        50.6%
#
#   G = modelo < Naive  |  P = modelo > Naive  |  % = victorias sobre 81 enlaces
#
# ############################################################
#   W=60 | H=5min | peso=0.75  —  8 modelos
# ############################################################
#
# ==========================================================================================
#   1 vs 1  ──  ARIMA  |  W=60 | H=5min | peso=0.75
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        12/81        69/81        14.8%        18/81        63/81        22.2%        31/81        50/81        38.3%
#           Arq1_B         2/81        79/81         2.5%         5/81        76/81         6.2%        33/81        48/81        40.7%
#           Arq2_A        10/81        71/81        12.3%        14/81        67/81        17.3%        28/81        53/81        34.6%
#           Arq2_B         2/81        79/81         2.5%         5/81        76/81         6.2%        33/81        48/81        40.7%
#           Arq3_A        11/81        70/81        13.6%        17/81        64/81        21.0%        29/81        52/81        35.8%
#           Arq3_B         2/81        79/81         2.5%         5/81        76/81         6.2%        32/81        49/81        39.5%
#           Arq4_A        11/81        70/81        13.6%        13/81        68/81        16.0%        27/81        54/81        33.3%
#           Arq4_B         2/81        79/81         2.5%         5/81        76/81         6.2%        32/81        49/81        39.5%
#
#   G = modelo < ARIMA  |  P = modelo > ARIMA  |  % = victorias sobre 81 enlaces
#
# ==========================================================================================
#   1 vs 1  ──  Naive  |  W=60 | H=5min | peso=0.75
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        28/81        53/81        34.6%        39/81        42/81        48.1%        30/81        51/81        37.0%
#           Arq1_B         2/81        79/81         2.5%         9/81        72/81        11.1%        32/81        49/81        39.5%
#           Arq2_A        25/81        56/81        30.9%        34/81        47/81        42.0%        27/81        54/81        33.3%
#           Arq2_B         2/81        79/81         2.5%         9/81        72/81        11.1%        31/81        50/81        38.3%
#           Arq3_A        26/81        55/81        32.1%        40/81        41/81        49.4%        30/81        51/81        37.0%
#           Arq3_B         2/81        79/81         2.5%         9/81        72/81        11.1%        31/81        50/81        38.3%
#           Arq4_A        22/81        59/81        27.2%        29/81        52/81        35.8%        24/81        57/81        29.6%
#           Arq4_B         2/81        79/81         2.5%         9/81        72/81        11.1%        32/81        49/81        39.5%
#
#   G = modelo < Naive  |  P = modelo > Naive  |  % = victorias sobre 81 enlaces
#
# ############################################################
#   W=60 | H=15min | peso=0.00  —  8 modelos
# ############################################################
#
# ==========================================================================================
#   1 vs 1  ──  ARIMA  |  W=60 | H=15min | peso=0.00
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A         5/81        76/81         6.2%        11/81        70/81        13.6%        36/81        45/81        44.4%
#           Arq1_B        34/81        47/81        42.0%        36/81        45/81        44.4%        66/81        15/81        81.5%
#           Arq2_A         3/81        78/81         3.7%        11/81        70/81        13.6%        39/81        42/81        48.1%
#           Arq2_B        31/81        50/81        38.3%        37/81        44/81        45.7%        67/81        14/81        82.7%
#           Arq3_A         5/81        76/81         6.2%        11/81        70/81        13.6%        37/81        44/81        45.7%
#           Arq3_B        27/81        54/81        33.3%        35/81        46/81        43.2%        66/81        15/81        81.5%
#           Arq4_A         2/81        79/81         2.5%         9/81        72/81        11.1%        34/81        47/81        42.0%
#           Arq4_B        30/81        51/81        37.0%        37/81        44/81        45.7%        64/81        17/81        79.0%
#
#   G = modelo < ARIMA  |  P = modelo > ARIMA  |  % = victorias sobre 81 enlaces
#
# ==========================================================================================
#   1 vs 1  ──  Naive  |  W=60 | H=15min | peso=0.00
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        22/81        59/81        27.2%        25/81        56/81        30.9%        39/81        41/81        48.1%
#           Arq1_B        44/81        37/81        54.3%        44/81        37/81        54.3%        65/81        16/81        80.2%
#           Arq2_A        27/81        54/81        33.3%        27/81        54/81        33.3%        44/81        37/81        54.3%
#           Arq2_B        35/81        46/81        43.2%        41/81        40/81        50.6%        67/81        14/81        82.7%
#           Arq3_A        18/81        63/81        22.2%        27/81        54/81        33.3%        42/81        39/81        51.9%
#           Arq3_B        33/81        48/81        40.7%        44/81        37/81        54.3%        68/81        13/81        84.0%
#           Arq4_A        24/81        57/81        29.6%        31/81        50/81        38.3%        45/81        36/81        55.6%
#           Arq4_B        38/81        43/81        46.9%        47/81        34/81        58.0%        63/81        18/81        77.8%
#
#   G = modelo < Naive  |  P = modelo > Naive  |  % = victorias sobre 81 enlaces
#
# ############################################################
#   W=60 | H=15min | peso=0.25  —  8 modelos
# ############################################################
#
# ==========================================================================================
#   1 vs 1  ──  ARIMA  |  W=60 | H=15min | peso=0.25
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A         9/81        72/81        11.1%        16/81        65/81        19.8%        33/81        48/81        40.7%
#           Arq1_B        18/81        63/81        22.2%        26/81        55/81        32.1%        69/81        12/81        85.2%
#           Arq2_A         7/81        74/81         8.6%        17/81        64/81        21.0%        30/81        51/81        37.0%
#           Arq2_B        19/81        62/81        23.5%        26/81        55/81        32.1%        70/81        11/81        86.4%
#           Arq3_A        10/81        71/81        12.3%        15/81        66/81        18.5%        30/81        51/81        37.0%
#           Arq3_B        20/81        61/81        24.7%        26/81        55/81        32.1%        69/81        12/81        85.2%
#           Arq4_A         9/81        72/81        11.1%        15/81        66/81        18.5%        24/81        57/81        29.6%
#           Arq4_B        22/81        59/81        27.2%        26/81        55/81        32.1%        70/81        11/81        86.4%
#
#   G = modelo < ARIMA  |  P = modelo > ARIMA  |  % = victorias sobre 81 enlaces
#
# ==========================================================================================
#   1 vs 1  ──  Naive  |  W=60 | H=15min | peso=0.25
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        23/81        58/81        28.4%        33/81        48/81        40.7%        31/81        50/81        38.3%
#           Arq1_B        20/81        61/81        24.7%        33/81        48/81        40.7%        71/81        10/81        87.7%
#           Arq2_A        27/81        54/81        33.3%        34/81        47/81        42.0%        33/81        48/81        40.7%
#           Arq2_B        20/81        61/81        24.7%        30/81        51/81        37.0%        73/81         8/81        90.1%
#           Arq3_A        23/81        58/81        28.4%        30/81        51/81        37.0%        28/81        53/81        34.6%
#           Arq3_B        20/81        61/81        24.7%        32/81        49/81        39.5%        74/81         7/81        91.4%
#           Arq4_A        23/81        58/81        28.4%        28/81        53/81        34.6%        25/81        56/81        30.9%
#           Arq4_B        22/81        59/81        27.2%        33/81        48/81        40.7%        72/81         9/81        88.9%
#
#   G = modelo < Naive  |  P = modelo > Naive  |  % = victorias sobre 81 enlaces
#
# ############################################################
#   W=60 | H=15min | peso=0.50  —  8 modelos
# ############################################################
#
# ==========================================================================================
#   1 vs 1  ──  ARIMA  |  W=60 | H=15min | peso=0.50
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        13/81        68/81        16.0%        27/81        54/81        33.3%        35/81        46/81        43.2%
#           Arq1_B         6/81        75/81         7.4%        13/81        68/81        16.0%        59/81        22/81        72.8%
#           Arq2_A         9/81        72/81        11.1%        19/81        62/81        23.5%        27/81        54/81        33.3%
#           Arq2_B         6/81        75/81         7.4%        12/81        69/81        14.8%        61/81        20/81        75.3%
#           Arq3_A        12/81        69/81        14.8%        19/81        62/81        23.5%        26/81        55/81        32.1%
#           Arq3_B         5/81        76/81         6.2%        12/81        69/81        14.8%        60/81        21/81        74.1%
#           Arq4_A         8/81        73/81         9.9%        16/81        65/81        19.8%        25/81        56/81        30.9%
#           Arq4_B         4/81        77/81         4.9%        11/81        70/81        13.6%        60/81        21/81        74.1%
#
#   G = modelo < ARIMA  |  P = modelo > ARIMA  |  % = victorias sobre 81 enlaces
#
# ==========================================================================================
#   1 vs 1  ──  Naive  |  W=60 | H=15min | peso=0.50
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        31/81        50/81        38.3%        42/81        39/81        51.9%        30/81        51/81        37.0%
#           Arq1_B         9/81        72/81        11.1%        24/81        57/81        29.6%        62/81        19/81        76.5%
#           Arq2_A        24/81        57/81        29.6%        33/81        48/81        40.7%        24/81        57/81        29.6%
#           Arq2_B         8/81        73/81         9.9%        20/81        61/81        24.7%        63/81        18/81        77.8%
#           Arq3_A        26/81        55/81        32.1%        38/81        43/81        46.9%        24/81        57/81        29.6%
#           Arq3_B         9/81        72/81        11.1%        21/81        60/81        25.9%        61/81        20/81        75.3%
#           Arq4_A        21/81        60/81        25.9%        34/81        47/81        42.0%        20/81        61/81        24.7%
#           Arq4_B         7/81        74/81         8.6%        22/81        59/81        27.2%        64/81        17/81        79.0%
#
#   G = modelo < Naive  |  P = modelo > Naive  |  % = victorias sobre 81 enlaces
#
# ############################################################
#   W=60 | H=15min | peso=0.75  —  8 modelos
# ############################################################
#
# ==========================================================================================
#   1 vs 1  ──  ARIMA  |  W=60 | H=15min | peso=0.75
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        13/81        68/81        16.0%        20/81        61/81        24.7%        23/81        58/81        28.4%
#           Arq1_B         2/81        79/81         2.5%        10/81        71/81        12.3%        53/81        28/81        65.4%
#           Arq2_A         8/81        73/81         9.9%        16/81        65/81        19.8%        20/81        61/81        24.7%
#           Arq2_B         2/81        79/81         2.5%        11/81        70/81        13.6%        53/81        28/81        65.4%
#           Arq3_A         9/81        72/81        11.1%        17/81        64/81        21.0%        24/81        57/81        29.6%
#           Arq3_B         2/81        79/81         2.5%        10/81        71/81        12.3%        53/81        28/81        65.4%
#           Arq4_A         7/81        74/81         8.6%        14/81        67/81        17.3%        23/81        58/81        28.4%
#           Arq4_B         2/81        79/81         2.5%        10/81        71/81        12.3%        54/81        27/81        66.7%
#
#   G = modelo < ARIMA  |  P = modelo > ARIMA  |  % = victorias sobre 81 enlaces
#
# ==========================================================================================
#   1 vs 1  ──  Naive  |  W=60 | H=15min | peso=0.75
# ==========================================================================================
#           Modelo     MAE Gana   MAE Pierde     MAE %Win    RMSE Gana  RMSE Pierde    RMSE %Win    MAPE Gana  MAPE Pierde    MAPE %Win
# -------------------------------------------------------------------------------------------------------------------------------------
#           Arq1_A        27/81        54/81        33.3%        31/81        50/81        38.3%        23/81        58/81        28.4%
#           Arq1_B         2/81        79/81         2.5%        17/81        64/81        21.0%        53/81        28/81        65.4%
#           Arq2_A        21/81        60/81        25.9%        29/81        52/81        35.8%        21/81        60/81        25.9%
#           Arq2_B         2/81        79/81         2.5%        17/81        64/81        21.0%        53/81        28/81        65.4%
#           Arq3_A        24/81        57/81        29.6%        35/81        46/81        43.2%        27/81        54/81        33.3%
#           Arq3_B         2/81        79/81         2.5%        17/81        64/81        21.0%        53/81        28/81        65.4%
#           Arq4_A        17/81        64/81        21.0%        34/81        47/81        42.0%        19/81        62/81        23.5%
#           Arq4_B         2/81        79/81         2.5%        17/81        64/81        21.0%        53/81        28/81        65.4%
#
#   G = modelo < Naive  |  P = modelo > Naive  |  % = victorias sobre 81 enlaces
#
# 💾 CSV guardado: Results_min/1v1_resumen_min.csv
